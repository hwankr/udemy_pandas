# %% [markdown]
# # Table Styling

# %%
import pandas as pd

# %% [markdown]
# ## The Styler Object
# - The `style` attribute on a `DataFrame` returns a `Styler` object.
# - A `Styler` renders an HTML table with CSS styles in Jupyter notebooks.
# - The `Styler` does not change the underlying data, only its presentation.
# - Methods on the `Styler` can customize formatting, colors, highlights, and more.
# - The `Styler`'s string representation is the `DataFrame` itself (it's a weird design decision).

# %%
report_card = pd.read_csv("superhero_academy.csv", index_col="Hero")
report_card
# Out:
#           Flying  Strength  Stealth  Telepathy  Gadgets
# Hero
# Zoom        85.0      70.0       90       60.0       95
# Mentalis    92.0      55.0       40       88.0       78
# Titan       45.0      98.0       30        NaN       55
# Shadow       NaN      82.0       95       75.0       90
# Psi-Kid     78.0       NaN       65       92.0       45
# Specter     95.0      60.0       88       35.0       70

# %%
type(report_card.style)
# Out:
# pandas.io.formats.style.Styler

# %% [markdown]
# - The `style.set_caption` method adds a title above the styled table.
# - Methods on the `Styler` return a new `DataFrame`.

# %%
report_card.style.set_caption("Superhero Academy -- Report Card")
# Out:
# <style type="text/css">
# </style>
# <table id="T_47412">
#   <caption>Superhero Academy -- Report Card</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47412_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_47412_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_47412_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_47412_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_47412_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47412_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_47412_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_47412_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_47412_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_47412_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_47412_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_47412_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_47412_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_47412_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_47412_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_47412_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_47412_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_47412_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_47412_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_47412_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_47412_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_47412_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_47412_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_47412_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_47412_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_47412_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_47412_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_47412_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_47412_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_47412_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_47412_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_47412_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_47412_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_47412_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_47412_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_47412_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_47412_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_47412_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_47412_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_47412_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_47412_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - The `style.format` method alters the presentation of values.
# - The `precision` parameter sets the number of places after the decimal point.
# - The `na_rep` parameter sets a string to display in place of `NaN` values.

# %%
report_card.style.format(precision=2, na_rep="--")
# Out:
# <style type="text/css">
# </style>
# <table id="T_21fbd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21fbd_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_21fbd_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_21fbd_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_21fbd_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_21fbd_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21fbd_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_21fbd_row0_col0" class="data row0 col0" >85.00</td>
#       <td id="T_21fbd_row0_col1" class="data row0 col1" >70.00</td>
#       <td id="T_21fbd_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_21fbd_row0_col3" class="data row0 col3" >60.00</td>
#       <td id="T_21fbd_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_21fbd_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_21fbd_row1_col0" class="data row1 col0" >92.00</td>
#       <td id="T_21fbd_row1_col1" class="data row1 col1" >55.00</td>
#       <td id="T_21fbd_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_21fbd_row1_col3" class="data row1 col3" >88.00</td>
#       <td id="T_21fbd_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_21fbd_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_21fbd_row2_col0" class="data row2 col0" >45.00</td>
#       <td id="T_21fbd_row2_col1" class="data row2 col1" >98.00</td>
#       <td id="T_21fbd_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_21fbd_row2_col3" class="data row2 col3" >--</td>
#       <td id="T_21fbd_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_21fbd_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_21fbd_row3_col0" class="data row3 col0" >--</td>
#       <td id="T_21fbd_row3_col1" class="data row3 col1" >82.00</td>
#       <td id="T_21fbd_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_21fbd_row3_col3" class="data row3 col3" >75.00</td>
#       <td id="T_21fbd_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_21fbd_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_21fbd_row4_col0" class="data row4 col0" >78.00</td>
#       <td id="T_21fbd_row4_col1" class="data row4 col1" >--</td>
#       <td id="T_21fbd_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_21fbd_row4_col3" class="data row4 col3" >92.00</td>
#       <td id="T_21fbd_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_21fbd_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_21fbd_row5_col0" class="data row5 col0" >95.00</td>
#       <td id="T_21fbd_row5_col1" class="data row5 col1" >60.00</td>
#       <td id="T_21fbd_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_21fbd_row5_col3" class="data row5 col3" >35.00</td>
#       <td id="T_21fbd_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Methods on the `Styler` return the `Styler`, so we can use method chaining.
# - We do _not_ need to access `style` again because a `Styler` method does not return the `DataFrame`.

# %%
report_card.style.format(precision=2, na_rep="--").set_caption(
    "Superhero Academy -- Report Card"
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9eb94">
#   <caption>Superhero Academy -- Report Card</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9eb94_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_9eb94_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_9eb94_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_9eb94_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_9eb94_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9eb94_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_9eb94_row0_col0" class="data row0 col0" >85.00</td>
#       <td id="T_9eb94_row0_col1" class="data row0 col1" >70.00</td>
#       <td id="T_9eb94_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_9eb94_row0_col3" class="data row0 col3" >60.00</td>
#       <td id="T_9eb94_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_9eb94_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_9eb94_row1_col0" class="data row1 col0" >92.00</td>
#       <td id="T_9eb94_row1_col1" class="data row1 col1" >55.00</td>
#       <td id="T_9eb94_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_9eb94_row1_col3" class="data row1 col3" >88.00</td>
#       <td id="T_9eb94_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_9eb94_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_9eb94_row2_col0" class="data row2 col0" >45.00</td>
#       <td id="T_9eb94_row2_col1" class="data row2 col1" >98.00</td>
#       <td id="T_9eb94_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_9eb94_row2_col3" class="data row2 col3" >--</td>
#       <td id="T_9eb94_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_9eb94_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_9eb94_row3_col0" class="data row3 col0" >--</td>
#       <td id="T_9eb94_row3_col1" class="data row3 col1" >82.00</td>
#       <td id="T_9eb94_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_9eb94_row3_col3" class="data row3 col3" >75.00</td>
#       <td id="T_9eb94_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_9eb94_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_9eb94_row4_col0" class="data row4 col0" >78.00</td>
#       <td id="T_9eb94_row4_col1" class="data row4 col1" >--</td>
#       <td id="T_9eb94_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_9eb94_row4_col3" class="data row4 col3" >92.00</td>
#       <td id="T_9eb94_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_9eb94_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_9eb94_row5_col0" class="data row5 col0" >95.00</td>
#       <td id="T_9eb94_row5_col1" class="data row5 col1" >60.00</td>
#       <td id="T_9eb94_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_9eb94_row5_col3" class="data row5 col3" >35.00</td>
#       <td id="T_9eb94_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Hide Index or Column Labels
# - The `hide` method hides the row or column index.
# - Pass an argument of `axis="columns"` to hide the column headers.

# %%
report_card = pd.read_csv("superhero_academy.csv", index_col="Hero")
report_card
# Out:
#           Flying  Strength  Stealth  Telepathy  Gadgets
# Hero
# Zoom        85.0      70.0       90       60.0       95
# Mentalis    92.0      55.0       40       88.0       78
# Titan       45.0      98.0       30        NaN       55
# Shadow       NaN      82.0       95       75.0       90
# Psi-Kid     78.0       NaN       65       92.0       45
# Specter     95.0      60.0       88       35.0       70

# %%
report_card.style.hide()
report_card.style.hide(axis=0)
report_card.style.hide(axis="index")

report_card.style.hide(axis=1)
report_card.style.hide(axis="columns")

report_card.style.hide(axis="columns").hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e08cf">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e08cf_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_e08cf_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_e08cf_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_e08cf_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_e08cf_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <td id="T_e08cf_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_e08cf_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_e08cf_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_e08cf_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_e08cf_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <td id="T_e08cf_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_e08cf_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_e08cf_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_e08cf_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_e08cf_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <td id="T_e08cf_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_e08cf_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_e08cf_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_e08cf_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_e08cf_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <td id="T_e08cf_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_e08cf_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_e08cf_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_e08cf_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_e08cf_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <td id="T_e08cf_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_e08cf_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_e08cf_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_e08cf_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_e08cf_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Pass a `subset` parameter to hide specific rows or columns by label.

# %%
report_card.style.hide(subset=["Titan", "Shadow"], axis="index")

report_card.style.hide(subset=["Gadgets", "Telepathy"], axis="columns")

report_card.style.hide(subset=["Gadgets", "Telepathy"], axis="columns").hide(
    subset=["Titan", "Shadow"], axis="index"
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3c98b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c98b_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_3c98b_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_3c98b_level0_col2" class="col_heading level0 col2" >Stealth</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c98b_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_3c98b_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_3c98b_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_3c98b_row0_col2" class="data row0 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_3c98b_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_3c98b_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_3c98b_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_3c98b_row1_col2" class="data row1 col2" >40</td>
#     </tr>
#     <tr>
#       <th id="T_3c98b_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_3c98b_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_3c98b_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_3c98b_row4_col2" class="data row4 col2" >65</td>
#     </tr>
#     <tr>
#       <th id="T_3c98b_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_3c98b_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_3c98b_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_3c98b_row5_col2" class="data row5 col2" >88</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Highlighting Values
# - The `highlight_null` method colors the background of cells that contain `NaN`.
# - The default color is red. Use the `color` parameter to customize the highlight color.
# - Provide the 6-character hexadecimal color code or a color name (like `"gold"`).

# %%
report_card = pd.read_csv("superhero_academy.csv", index_col="Hero")
report_card
# Out:
#           Flying  Strength  Stealth  Telepathy  Gadgets
# Hero
# Zoom        85.0      70.0       90       60.0       95
# Mentalis    92.0      55.0       40       88.0       78
# Titan       45.0      98.0       30        NaN       55
# Shadow       NaN      82.0       95       75.0       90
# Psi-Kid     78.0       NaN       65       92.0       45
# Specter     95.0      60.0       88       35.0       70

# %%
report_card.style.highlight_null()
report_card.style.highlight_null(color="gold")
report_card.style.highlight_null(color="#ADD8E6")
# Out:
# <style type="text/css">
# #T_71ba6_row2_col3, #T_71ba6_row3_col0, #T_71ba6_row4_col1 {
#   background-color: #ADD8E6;
# }
# </style>
# <table id="T_71ba6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71ba6_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_71ba6_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_71ba6_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_71ba6_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_71ba6_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71ba6_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_71ba6_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_71ba6_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_71ba6_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_71ba6_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_71ba6_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_71ba6_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_71ba6_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_71ba6_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_71ba6_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_71ba6_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_71ba6_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_71ba6_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_71ba6_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_71ba6_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_71ba6_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_71ba6_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_71ba6_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_71ba6_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_71ba6_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_71ba6_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_71ba6_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_71ba6_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_71ba6_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_71ba6_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_71ba6_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_71ba6_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_71ba6_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_71ba6_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_71ba6_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_71ba6_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_71ba6_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_71ba6_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_71ba6_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_71ba6_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_71ba6_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - The `highlight_max` and `highlight_min` methods color the highest and lowest values.
# - The `axis` parameter controls direction. `0` is max/min per-column, `1` is max/min per-row, or `None` for the entire table.
# - The `color` parameter sets the highlight color.

# %%
report_card.style.highlight_max(color="#D4EDDA", axis=0)
report_card.style.highlight_max(color="#D4EDDA", axis="index")

report_card.style.highlight_min(color="#F8D7DA", axis=0)

report_card.style.highlight_max(color="#D4EDDA", axis=0).highlight_min(
    color="#F8D7DA", axis=0
)
# Out:
# <style type="text/css">
# #T_4a9cf_row0_col4, #T_4a9cf_row2_col1, #T_4a9cf_row3_col2, #T_4a9cf_row4_col3, #T_4a9cf_row5_col0 {
#   background-color: #D4EDDA;
# }
# #T_4a9cf_row1_col1, #T_4a9cf_row2_col0, #T_4a9cf_row2_col2, #T_4a9cf_row4_col4, #T_4a9cf_row5_col3 {
#   background-color: #F8D7DA;
# }
# </style>
# <table id="T_4a9cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a9cf_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_4a9cf_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_4a9cf_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_4a9cf_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_4a9cf_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a9cf_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_4a9cf_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_4a9cf_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_4a9cf_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_4a9cf_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_4a9cf_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_4a9cf_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_4a9cf_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_4a9cf_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_4a9cf_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_4a9cf_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_4a9cf_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_4a9cf_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_4a9cf_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_4a9cf_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_4a9cf_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_4a9cf_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_4a9cf_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_4a9cf_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_4a9cf_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_4a9cf_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_4a9cf_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_4a9cf_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_4a9cf_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_4a9cf_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_4a9cf_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_4a9cf_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_4a9cf_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_4a9cf_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_4a9cf_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_4a9cf_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_4a9cf_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_4a9cf_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_4a9cf_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_4a9cf_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_4a9cf_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %%
report_card.style.highlight_max(color="#D4EDDA", axis=1).highlight_min(
    color="#F8D7DA", axis=1
)

report_card.style.highlight_max(color="#D4EDDA", axis="columns").highlight_min(
    color="#F8D7DA", axis="columns"
)
# Out:
# <style type="text/css">
# #T_04189_row0_col3, #T_04189_row1_col2, #T_04189_row2_col2, #T_04189_row3_col3, #T_04189_row4_col4, #T_04189_row5_col3 {
#   background-color: #F8D7DA;
# }
# #T_04189_row0_col4, #T_04189_row1_col0, #T_04189_row2_col1, #T_04189_row3_col2, #T_04189_row4_col3, #T_04189_row5_col0 {
#   background-color: #D4EDDA;
# }
# </style>
# <table id="T_04189">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04189_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_04189_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_04189_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_04189_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_04189_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04189_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_04189_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_04189_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_04189_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_04189_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_04189_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_04189_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_04189_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_04189_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_04189_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_04189_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_04189_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_04189_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_04189_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_04189_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_04189_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_04189_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_04189_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_04189_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_04189_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_04189_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_04189_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_04189_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_04189_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_04189_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_04189_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_04189_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_04189_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_04189_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_04189_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_04189_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_04189_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_04189_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_04189_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_04189_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_04189_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %%
report_card.style.highlight_max(color="#D4EDDA", axis=None).highlight_min(
    color="#F8D7DA", axis=None
)
# Out:
# <style type="text/css">
# #T_b3179_row2_col1 {
#   background-color: #D4EDDA;
# }
# #T_b3179_row2_col2 {
#   background-color: #F8D7DA;
# }
# </style>
# <table id="T_b3179">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3179_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_b3179_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_b3179_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_b3179_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_b3179_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3179_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_b3179_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_b3179_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_b3179_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_b3179_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_b3179_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_b3179_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_b3179_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_b3179_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_b3179_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_b3179_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_b3179_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_b3179_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_b3179_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_b3179_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_b3179_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_b3179_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_b3179_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_b3179_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_b3179_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_b3179_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_b3179_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_b3179_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_b3179_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_b3179_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_b3179_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_b3179_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_b3179_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_b3179_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_b3179_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_b3179_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_b3179_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_b3179_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_b3179_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_b3179_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_b3179_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - The `highlight_between` method colors values that fall within a given range.
# - The `left` and `right` parameters set the lower and upper bounds. Both are inclusive.

# %%
report_card.style.highlight_between(left=90, right=100, color="#D4EDDA")
# Out:
# <style type="text/css">
# #T_496bf_row0_col2, #T_496bf_row0_col4, #T_496bf_row1_col0, #T_496bf_row2_col1, #T_496bf_row3_col2, #T_496bf_row3_col4, #T_496bf_row4_col3, #T_496bf_row5_col0 {
#   background-color: #D4EDDA;
# }
# </style>
# <table id="T_496bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_496bf_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_496bf_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_496bf_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_496bf_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_496bf_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_496bf_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_496bf_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_496bf_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_496bf_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_496bf_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_496bf_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_496bf_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_496bf_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_496bf_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_496bf_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_496bf_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_496bf_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_496bf_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_496bf_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_496bf_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_496bf_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_496bf_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_496bf_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_496bf_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_496bf_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_496bf_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_496bf_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_496bf_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_496bf_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_496bf_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_496bf_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_496bf_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_496bf_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_496bf_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_496bf_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_496bf_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_496bf_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_496bf_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_496bf_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_496bf_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_496bf_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Using Color Gradients
#
# - The `background_gradient` method creates a heatmap across cells.
# - Greater values will have a deeper shade of color.
# - The `cmap` parameter accepts any Matplotlib colormap (e.g., `"YlOrRd"`, `"Blues"`, `"viridis"`).
# - The `axis` parameter controls direction: `0` per-column, `1` per-row, `None` for the full table.
#
# <img src= "assets/matplotlib_colormaps.webp" width="500"/>

# %%
report_card = pd.read_csv("superhero_academy.csv", index_col="Hero")
report_card
# Out:
#           Flying  Strength  Stealth  Telepathy  Gadgets
# Hero
# Zoom        85.0      70.0       90       60.0       95
# Mentalis    92.0      55.0       40       88.0       78
# Titan       45.0      98.0       30        NaN       55
# Shadow       NaN      82.0       95       75.0       90
# Psi-Kid     78.0       NaN       65       92.0       45
# Specter     95.0      60.0       88       35.0       70

# %%
report_card.style.background_gradient()
report_card.style.background_gradient(axis=0)
report_card.style.background_gradient(axis=1)
report_card.style.background_gradient(axis=1, cmap="Blues")
report_card.style.background_gradient(axis=1, cmap="Reds")
report_card.style.background_gradient(axis=1, cmap="YlGn")
# Out:
# <style type="text/css">
# #T_4c051_row0_col0 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_4c051_row0_col1, #T_4c051_row1_col1 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_4c051_row0_col2 {
#   background-color: #056c39;
#   color: #f1f1f1;
# }
# #T_4c051_row0_col3, #T_4c051_row1_col2, #T_4c051_row2_col2, #T_4c051_row3_col3, #T_4c051_row4_col4, #T_4c051_row5_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_4c051_row0_col4, #T_4c051_row1_col0, #T_4c051_row2_col1, #T_4c051_row3_col2, #T_4c051_row4_col3, #T_4c051_row5_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_4c051_row1_col3 {
#   background-color: #005a31;
#   color: #f1f1f1;
# }
# #T_4c051_row1_col4 {
#   background-color: #278946;
#   color: #f1f1f1;
# }
# #T_4c051_row2_col0 {
#   background-color: #e0f3a8;
#   color: #000000;
# }
# #T_4c051_row2_col3, #T_4c051_row3_col0, #T_4c051_row4_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4c051_row2_col4 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_4c051_row3_col1 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_4c051_row3_col4 {
#   background-color: #228343;
#   color: #f1f1f1;
# }
# #T_4c051_row4_col0 {
#   background-color: #2f934d;
#   color: #f1f1f1;
# }
# #T_4c051_row4_col2 {
#   background-color: #98d486;
#   color: #000000;
# }
# #T_4c051_row5_col1 {
#   background-color: #9cd687;
#   color: #000000;
# }
# #T_4c051_row5_col2 {
#   background-color: #006536;
#   color: #f1f1f1;
# }
# #T_4c051_row5_col4 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4c051">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c051_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_4c051_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_4c051_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_4c051_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_4c051_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c051_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_4c051_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_4c051_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_4c051_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_4c051_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_4c051_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_4c051_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_4c051_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_4c051_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_4c051_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_4c051_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_4c051_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_4c051_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_4c051_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_4c051_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_4c051_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_4c051_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_4c051_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_4c051_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_4c051_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_4c051_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_4c051_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_4c051_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_4c051_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_4c051_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_4c051_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_4c051_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_4c051_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_4c051_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_4c051_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_4c051_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_4c051_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_4c051_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_4c051_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_4c051_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_4c051_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - The `subset` parameter applies the gradient to specific columns only.
# - The `vmin` and `vmax` parameters set the boundaries of the range used for color scaling.
# - By default, `vmin` is the smallest value and `vmax` is the largest value.

# %%
report_card.style.background_gradient(subset=["Flying", "Stealth"])
report_card.style.background_gradient(subset=["Flying", "Stealth"], vmin=80, vmax=100)
# Out:
# <style type="text/css">
# #T_bad29_row0_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_bad29_row0_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_bad29_row1_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_bad29_row1_col2, #T_bad29_row2_col0, #T_bad29_row2_col2, #T_bad29_row4_col0, #T_bad29_row4_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bad29_row3_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_bad29_row3_col2, #T_bad29_row5_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_bad29_row5_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# </style>
# <table id="T_bad29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bad29_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_bad29_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_bad29_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_bad29_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_bad29_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bad29_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_bad29_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_bad29_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_bad29_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_bad29_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_bad29_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_bad29_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_bad29_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_bad29_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_bad29_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_bad29_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_bad29_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_bad29_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_bad29_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_bad29_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_bad29_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_bad29_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_bad29_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_bad29_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_bad29_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_bad29_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_bad29_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_bad29_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_bad29_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_bad29_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_bad29_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_bad29_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_bad29_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_bad29_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_bad29_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_bad29_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_bad29_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_bad29_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_bad29_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_bad29_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_bad29_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - The `text_gradient` method applies the color gradient to the text instead of the background.

# %%
report_card.style.text_gradient()
report_card.style.text_gradient(cmap="Reds")
report_card.style.text_gradient(cmap="Blues", vmin=0, vmax=100)
# Out:
# <style type="text/css">
# #T_91dbb_row0_col0 {
#   color: #0d57a1;
# }
# #T_91dbb_row0_col1, #T_91dbb_row5_col4 {
#   color: #2e7ebc;
# }
# #T_91dbb_row0_col2, #T_91dbb_row3_col4 {
#   color: #084a91;
# }
# #T_91dbb_row0_col3, #T_91dbb_row5_col1 {
#   color: #4a98c9;
# }
# #T_91dbb_row0_col4, #T_91dbb_row3_col2, #T_91dbb_row5_col0 {
#   color: #083c7d;
# }
# #T_91dbb_row1_col0, #T_91dbb_row4_col3 {
#   color: #08458a;
# }
# #T_91dbb_row1_col1, #T_91dbb_row2_col4 {
#   color: #5ba3d0;
# }
# #T_91dbb_row1_col2 {
#   color: #94c4df;
# }
# #T_91dbb_row1_col3, #T_91dbb_row5_col2 {
#   color: #084f99;
# }
# #T_91dbb_row1_col4, #T_91dbb_row4_col0 {
#   color: #1b69af;
# }
# #T_91dbb_row2_col0, #T_91dbb_row4_col4 {
#   color: #7fb9da;
# }
# #T_91dbb_row2_col1 {
#   color: #083573;
# }
# #T_91dbb_row2_col2 {
#   color: #b7d4ea;
# }
# #T_91dbb_row2_col3, #T_91dbb_row3_col0, #T_91dbb_row4_col1 {
#   color: #000000;
# }
# #T_91dbb_row3_col1 {
#   color: #135fa7;
# }
# #T_91dbb_row3_col3 {
#   color: #2070b4;
# }
# #T_91dbb_row4_col2 {
#   color: #3b8bc2;
# }
# #T_91dbb_row5_col3 {
#   color: #a6cee4;
# }
# </style>
# <table id="T_91dbb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91dbb_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_91dbb_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_91dbb_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_91dbb_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_91dbb_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91dbb_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_91dbb_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_91dbb_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_91dbb_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_91dbb_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_91dbb_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_91dbb_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_91dbb_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_91dbb_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_91dbb_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_91dbb_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_91dbb_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_91dbb_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_91dbb_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_91dbb_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_91dbb_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_91dbb_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_91dbb_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_91dbb_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_91dbb_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_91dbb_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_91dbb_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_91dbb_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_91dbb_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_91dbb_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_91dbb_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_91dbb_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_91dbb_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_91dbb_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_91dbb_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_91dbb_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_91dbb_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_91dbb_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_91dbb_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_91dbb_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_91dbb_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## In-Cell Bar Charts
#
# - The `bar` method draws horizontal bars inside cells, proportional to each value.
# - The `color` parameter sets the bar color.
# - The `vmin` and `vmax` parameters control the bar scale.

# %%
report_card = pd.read_csv("superhero_academy.csv", index_col="Hero")
report_card
# Out:
#           Flying  Strength  Stealth  Telepathy  Gadgets
# Hero
# Zoom        85.0      70.0       90       60.0       95
# Mentalis    92.0      55.0       40       88.0       78
# Titan       45.0      98.0       30        NaN       55
# Shadow       NaN      82.0       95       75.0       90
# Psi-Kid     78.0       NaN       65       92.0       45
# Specter     95.0      60.0       88       35.0       70

# %%
report_card.style.bar(color="#5FBADB", vmin=0, vmax=100)
# Out:
# <style type="text/css">
# #T_e74a1_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 85.0%, transparent 85.0%);
# }
# #T_e74a1_row0_col1, #T_e74a1_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 70.0%, transparent 70.0%);
# }
# #T_e74a1_row0_col2, #T_e74a1_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 90.0%, transparent 90.0%);
# }
# #T_e74a1_row0_col3, #T_e74a1_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 60.0%, transparent 60.0%);
# }
# #T_e74a1_row0_col4, #T_e74a1_row3_col2, #T_e74a1_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 95.0%, transparent 95.0%);
# }
# #T_e74a1_row1_col0, #T_e74a1_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 92.0%, transparent 92.0%);
# }
# #T_e74a1_row1_col1, #T_e74a1_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 55.0%, transparent 55.0%);
# }
# #T_e74a1_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 40.0%, transparent 40.0%);
# }
# #T_e74a1_row1_col3, #T_e74a1_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 88.0%, transparent 88.0%);
# }
# #T_e74a1_row1_col4, #T_e74a1_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 78.0%, transparent 78.0%);
# }
# #T_e74a1_row2_col0, #T_e74a1_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 45.0%, transparent 45.0%);
# }
# #T_e74a1_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 98.0%, transparent 98.0%);
# }
# #T_e74a1_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 30.0%, transparent 30.0%);
# }
# #T_e74a1_row2_col3, #T_e74a1_row3_col0, #T_e74a1_row4_col1 {
#   width: 10em;
# }
# #T_e74a1_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 82.0%, transparent 82.0%);
# }
# #T_e74a1_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 75.0%, transparent 75.0%);
# }
# #T_e74a1_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 65.0%, transparent 65.0%);
# }
# #T_e74a1_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5FBADB 35.0%, transparent 35.0%);
# }
# </style>
# <table id="T_e74a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e74a1_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_e74a1_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_e74a1_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_e74a1_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_e74a1_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e74a1_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_e74a1_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_e74a1_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_e74a1_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_e74a1_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_e74a1_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_e74a1_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_e74a1_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_e74a1_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_e74a1_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_e74a1_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_e74a1_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_e74a1_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_e74a1_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_e74a1_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_e74a1_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_e74a1_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_e74a1_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_e74a1_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_e74a1_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_e74a1_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_e74a1_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_e74a1_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_e74a1_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_e74a1_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_e74a1_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_e74a1_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_e74a1_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_e74a1_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_e74a1_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_e74a1_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_e74a1_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_e74a1_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_e74a1_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_e74a1_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_e74a1_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - The `subset` parameter restricts bars to specific columns.

# %%
report_card.style.bar(color="#6C63FF", vmin=0, vmax=100, subset=["Flying", "Strength"])
# Out:
# <style type="text/css">
# #T_1f6b5_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #6C63FF 85.0%, transparent 85.0%);
# }
# #T_1f6b5_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #6C63FF 70.0%, transparent 70.0%);
# }
# #T_1f6b5_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #6C63FF 92.0%, transparent 92.0%);
# }
# #T_1f6b5_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #6C63FF 55.0%, transparent 55.0%);
# }
# #T_1f6b5_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #6C63FF 45.0%, transparent 45.0%);
# }
# #T_1f6b5_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #6C63FF 98.0%, transparent 98.0%);
# }
# #T_1f6b5_row3_col0, #T_1f6b5_row4_col1 {
#   width: 10em;
# }
# #T_1f6b5_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #6C63FF 82.0%, transparent 82.0%);
# }
# #T_1f6b5_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #6C63FF 78.0%, transparent 78.0%);
# }
# #T_1f6b5_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #6C63FF 95.0%, transparent 95.0%);
# }
# #T_1f6b5_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #6C63FF 60.0%, transparent 60.0%);
# }
# </style>
# <table id="T_1f6b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f6b5_level0_col0" class="col_heading level0 col0" >Flying</th>
#       <th id="T_1f6b5_level0_col1" class="col_heading level0 col1" >Strength</th>
#       <th id="T_1f6b5_level0_col2" class="col_heading level0 col2" >Stealth</th>
#       <th id="T_1f6b5_level0_col3" class="col_heading level0 col3" >Telepathy</th>
#       <th id="T_1f6b5_level0_col4" class="col_heading level0 col4" >Gadgets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hero</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f6b5_level0_row0" class="row_heading level0 row0" >Zoom</th>
#       <td id="T_1f6b5_row0_col0" class="data row0 col0" >85.000000</td>
#       <td id="T_1f6b5_row0_col1" class="data row0 col1" >70.000000</td>
#       <td id="T_1f6b5_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_1f6b5_row0_col3" class="data row0 col3" >60.000000</td>
#       <td id="T_1f6b5_row0_col4" class="data row0 col4" >95</td>
#     </tr>
#     <tr>
#       <th id="T_1f6b5_level0_row1" class="row_heading level0 row1" >Mentalis</th>
#       <td id="T_1f6b5_row1_col0" class="data row1 col0" >92.000000</td>
#       <td id="T_1f6b5_row1_col1" class="data row1 col1" >55.000000</td>
#       <td id="T_1f6b5_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_1f6b5_row1_col3" class="data row1 col3" >88.000000</td>
#       <td id="T_1f6b5_row1_col4" class="data row1 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_1f6b5_level0_row2" class="row_heading level0 row2" >Titan</th>
#       <td id="T_1f6b5_row2_col0" class="data row2 col0" >45.000000</td>
#       <td id="T_1f6b5_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_1f6b5_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_1f6b5_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_1f6b5_row2_col4" class="data row2 col4" >55</td>
#     </tr>
#     <tr>
#       <th id="T_1f6b5_level0_row3" class="row_heading level0 row3" >Shadow</th>
#       <td id="T_1f6b5_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_1f6b5_row3_col1" class="data row3 col1" >82.000000</td>
#       <td id="T_1f6b5_row3_col2" class="data row3 col2" >95</td>
#       <td id="T_1f6b5_row3_col3" class="data row3 col3" >75.000000</td>
#       <td id="T_1f6b5_row3_col4" class="data row3 col4" >90</td>
#     </tr>
#     <tr>
#       <th id="T_1f6b5_level0_row4" class="row_heading level0 row4" >Psi-Kid</th>
#       <td id="T_1f6b5_row4_col0" class="data row4 col0" >78.000000</td>
#       <td id="T_1f6b5_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_1f6b5_row4_col2" class="data row4 col2" >65</td>
#       <td id="T_1f6b5_row4_col3" class="data row4 col3" >92.000000</td>
#       <td id="T_1f6b5_row4_col4" class="data row4 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_1f6b5_level0_row5" class="row_heading level0 row5" >Specter</th>
#       <td id="T_1f6b5_row5_col0" class="data row5 col0" >95.000000</td>
#       <td id="T_1f6b5_row5_col1" class="data row5 col1" >60.000000</td>
#       <td id="T_1f6b5_row5_col2" class="data row5 col2" >88</td>
#       <td id="T_1f6b5_row5_col3" class="data row5 col3" >35.000000</td>
#       <td id="T_1f6b5_row5_col4" class="data row5 col4" >70</td>
#     </tr>
#   </tbody>
# </table>
