# %% [markdown]
# # Merging DataFrames

# %%
import pandas as pd

# %% [markdown]
# ## Our Datasets
# - Our datasets are located in multiple files in the `library/` folder.
# - The `books.csv` file stores the library's book catalog.
# - The `members.csv` file stores the library's registered members.
# - The `checkouts_jan` and `checkouts_feb` files stores borrowing records from January and February.

# %%
books = pd.read_csv("library/books.csv")
books.head()
# Out:
#    Book ID                    Title               Author        Genre
# 0        1    To Kill a Mockingbird           Harper Lee      Fiction
# 1        2                     1984        George Orwell      Fiction
# 2        3  A Brief History of Time      Stephen Hawking      Science
# 3        4         The Great Gatsby  F. Scott Fitzgerald      Fiction
# 4        5             Freakonomics        Steven Levitt  Non-Fiction

# %%
members = pd.read_csv("library/members.csv", parse_dates=["Signup Date"])
members.head()
# Out:
#    ID First Name Last Name                           Email Membership  \
# 0   1   Samantha  Anderson  samantha.anderson4@outlook.com      Basic
# 1   2       Jack    Wilson         jack.wilson87@proton.me      Basic
# 2   3       John     Brown          john.brown12@yahoo.com      Basic
# 3   4   Patricia    Bailey     patricia.bailey26@proton.me      Basic
# 4   5       Emma     Scott           emma.scott1@yahoo.com    Premium
#
#   Signup Date
# 0  2020-10-12
# 1  2022-05-14
# 2  2023-05-17
# 3  2022-07-08
# 4  2021-11-27

# %%
jan = pd.read_csv("library/checkouts_jan.csv")
feb = pd.read_csv("library/checkouts_feb.csv")
feb.head()
# Out:
#       Branch  Member ID  Book ID
# 0  Riverside         80        3
# 1   Eastgate        753       33
# 2   Downtown         39       19
# 3   Westside        300       30
# 4   Eastgate          5       13

# %%
books = pd.read_csv("library/books.csv")
members = pd.read_csv("library/members.csv", parse_dates=["Signup Date"])
jan = pd.read_csv("library/checkouts_jan.csv")
feb = pd.read_csv("library/checkouts_feb.csv")

# %% [markdown]
# ## The pd.concat Function I
# - The `concat` function concatenates one `DataFrame` to the end of another.
# - The original index labels will be kept by default. Set `ignore_index` to `True` to generate a new index.

# %%
books = pd.read_csv("library/books.csv")
members = pd.read_csv("library/members.csv", parse_dates=["Signup Date"])
jan = pd.read_csv("library/checkouts_jan.csv")
feb = pd.read_csv("library/checkouts_feb.csv")

# %%
jan.head(2)
# Out:
#       Branch  Member ID  Book ID
# 0   Westside        587        5
# 1  Northpark        158       25

# %%
feb.head(2)
# Out:
#       Branch  Member ID  Book ID
# 0  Riverside         80        3
# 1   Eastgate        753       33

# %%
len(jan)
len(feb)
# Out:
# 250

# %%
pd.concat([jan, feb])
pd.concat([jan, feb], ignore_index=False)
pd.concat([jan, feb], ignore_index=True)
# Out:
#         Branch  Member ID  Book ID
# 0     Westside        587        5
# 1    Northpark        158       25
# 2     Downtown        820       23
# 3     Downtown        800       29
# 4    Northpark        150       19
# ..         ...        ...      ...
# 495   Westside        616       16
# 496   Downtown         62       20
# 497  Riverside        502       35
# 498   Westside        484       17
# 499  Riverside        468       32
#
# [500 rows x 3 columns]

# %% [markdown]
# - The `keys` parameter creates a `MultiIndex` using the specified keys/labels.

# %%
pd.concat([jan, feb], keys=["January", "February"])
# Out:
#                  Branch  Member ID  Book ID
# January  0     Westside        587        5
#          1    Northpark        158       25
#          2     Downtown        820       23
#          3     Downtown        800       29
#          4    Northpark        150       19
# ...                 ...        ...      ...
# February 245   Westside        616       16
#          246   Downtown         62       20
#          247  Riverside        502       35
#          248   Westside        484       17
#          249  Riverside        468       32
#
# [500 rows x 3 columns]

# %% [markdown]
# ## The pd.concat Function II
# - Pandas concatenates the `DataFrame` objects along the row/index axis by default.
# - Pandas will include all columns that exist in either `DataFrame`. If there are no matching values, pandas will use `NaN` values.
# - Pass the `axis` parameter an argument of `"columns"` to concatenate on the column axis.

# %%
books = pd.read_csv("library/books.csv")
members = pd.read_csv("library/members.csv", parse_dates=["Signup Date"])
jan = pd.read_csv("library/checkouts_jan.csv")
feb = pd.read_csv("library/checkouts_feb.csv")

# %%
titles = books["Title"].to_frame()
titles.head()
# Out:
#                      Title
# 0    To Kill a Mockingbird
# 1                     1984
# 2  A Brief History of Time
# 3         The Great Gatsby
# 4             Freakonomics

# %%
authors = books["Author"].to_frame()
authors.head()
# Out:
#                 Author
# 0           Harper Lee
# 1        George Orwell
# 2      Stephen Hawking
# 3  F. Scott Fitzgerald
# 4        Steven Levitt

# %%
pd.concat([titles, authors])
# pd.concat([titles, authors], axis="index")
pd.concat([titles, authors], axis="columns")
# Out:
#                                     Title                  Author
# 0                   To Kill a Mockingbird              Harper Lee
# 1                                    1984           George Orwell
# 2                 A Brief History of Time         Stephen Hawking
# 3                        The Great Gatsby     F. Scott Fitzgerald
# 4                            Freakonomics           Steven Levitt
# 5                                    Dune           Frank Herbert
# 6                                Educated           Tara Westover
# 7                              The Hobbit          J.R.R. Tolkien
# 8                     Pride and Prejudice             Jane Austen
# 9                              Clean Code        Robert C. Martin
# 10                 The Catcher in the Rye           J.D. Salinger
# 11                        Brave New World           Aldous Huxley
# 12                          The Alchemist            Paulo Coelho
# 13  Harry Potter and the Sorcerer's Stone            J.K. Rowling
# 14                  The Lord of the Rings          J.R.R. Tolkien
# 15                              Jane Eyre        Charlotte Bronte
# 16                      Wuthering Heights            Emily Bronte
# 17             The Picture of Dorian Gray             Oscar Wilde
# 18                         Fahrenheit 451            Ray Bradbury
# 19                                 Cosmos              Carl Sagan
# 20                 Thinking Fast and Slow         Daniel Kahneman
# 21                      The Da Vinci Code               Dan Brown
# 22                              Gone Girl           Gillian Flynn
# 23                            The Martian               Andy Weir
# 24                          Atomic Habits             James Clear
# 25                               Outliers        Malcolm Gladwell
# 26          The Design of Everyday Things              Don Norman
# 27                           Ender's Game        Orson Scott Card
# 28                           Little Women       Louisa May Alcott
# 29                        Treasure Island  Robert Louis Stevenson
# 30                           Frankenstein            Mary Shelley
# 31                                Dracula             Bram Stoker
# 32                     The Silent Patient        Alex Michaelides
# 33                      Project Hail Mary               Andy Weir
# 34   A Short History of Nearly Everything             Bill Bryson

# %%
books = pd.read_csv("library/books.csv", index_col="Title")
books.head()
# Out:
#                          Book ID               Author        Genre
# Title
# To Kill a Mockingbird          1           Harper Lee      Fiction
# 1984                           2        George Orwell      Fiction
# A Brief History of Time        3      Stephen Hawking      Science
# The Great Gatsby               4  F. Scott Fitzgerald      Fiction
# Freakonomics                   5        Steven Levitt  Non-Fiction

# %%
first = books[["Book ID", "Author"]].sort_index()
first.head(3)
# Out:
#                                       Book ID           Author
# Title
# 1984                                        2    George Orwell
# A Brief History of Time                     3  Stephen Hawking
# A Short History of Nearly Everything       35      Bill Bryson

# %%
second = books[["Genre"]]
second.head(3)
# Out:
#                            Genre
# Title
# To Kill a Mockingbird    Fiction
# 1984                     Fiction
# A Brief History of Time  Science

# %%
pd.concat([first, second], axis="columns")
# Out:
#                                        Book ID                  Author  \
# Title
# 1984                                         2           George Orwell
# A Brief History of Time                      3         Stephen Hawking
# A Short History of Nearly Everything        35             Bill Bryson
# Atomic Habits                               25             James Clear
# Brave New World                             12           Aldous Huxley
# Clean Code                                  10        Robert C. Martin
# Cosmos                                      20              Carl Sagan
# Dracula                                     32             Bram Stoker
# Dune                                         6           Frank Herbert
# Educated                                     7           Tara Westover
# Ender's Game                                28        Orson Scott Card
# Fahrenheit 451                              19            Ray Bradbury
# Frankenstein                                31            Mary Shelley
# Freakonomics                                 5           Steven Levitt
# Gone Girl                                   23           Gillian Flynn
# Harry Potter and the Sorcerer's Stone       14            J.K. Rowling
# Jane Eyre                                   16        Charlotte Bronte
# Little Women                                29       Louisa May Alcott
# Outliers                                    26        Malcolm Gladwell
# Pride and Prejudice                          9             Jane Austen
# Project Hail Mary                           34               Andy Weir
# The Alchemist                               13            Paulo Coelho
# The Catcher in the Rye                      11           J.D. Salinger
# The Da Vinci Code                           22               Dan Brown
# The Design of Everyday Things               27              Don Norman
# The Great Gatsby                             4     F. Scott Fitzgerald
# The Hobbit                                   8          J.R.R. Tolkien
# The Lord of the Rings                       15          J.R.R. Tolkien
# The Martian                                 24               Andy Weir
# The Picture of Dorian Gray                  18             Oscar Wilde
# The Silent Patient                          33        Alex Michaelides
# Thinking Fast and Slow                      21         Daniel Kahneman
# To Kill a Mockingbird                        1              Harper Lee
# Treasure Island                             30  Robert Louis Stevenson
# Wuthering Heights                           17            Emily Bronte
#
#                                              Genre
# Title
# 1984                                       Fiction
# A Brief History of Time                    Science
# A Short History of Nearly Everything       Science
# Atomic Habits                          Non-Fiction
# Brave New World                            Fiction
# Clean Code                              Technology
# Cosmos                                     Science
# Dracula                                    Fiction
# Dune                                        Sci-Fi
# Educated                                    Memoir
# Ender's Game                                Sci-Fi
# Fahrenheit 451                              Sci-Fi
# Frankenstein                               Fiction
# Freakonomics                           Non-Fiction
# Gone Girl                                  Fiction
# Harry Potter and the Sorcerer's Stone      Fiction
# Jane Eyre                                  Fiction
# Little Women                               Fiction
# Outliers                               Non-Fiction
# Pride and Prejudice                        Fiction
# Project Hail Mary                           Sci-Fi
# The Alchemist                              Fiction
# The Catcher in the Rye                     Fiction
# The Da Vinci Code                          Fiction
# The Design of Everyday Things           Technology
# The Great Gatsby                           Fiction
# The Hobbit                                 Fiction
# The Lord of the Rings                      Fiction
# The Martian                                 Sci-Fi
# The Picture of Dorian Gray                 Fiction
# The Silent Patient                         Fiction
# Thinking Fast and Slow                 Non-Fiction
# To Kill a Mockingbird                      Fiction
# Treasure Island                            Fiction
# Wuthering Heights                          Fiction

# %% [markdown]
# ## Left Joins
# - The `merge` method joins two `DataFrame` objects together based on shared values in a column or an index.
# - A left join merges one `DataFrame` into another based on values in the first one.
# - The "left" `DataFrame` is the one we invoke the `merge` method on.
# - If the left `DataFrame`'s value is not found in the right `DataFrame`, the row will hold `NaN` values.
# <img src="assets/SQL_Joins.png" width="800" height="800"/>

# %%
books = pd.read_csv("library/books.csv")
members = pd.read_csv("library/members.csv", parse_dates=["Signup Date"])
jan = pd.read_csv("library/checkouts_jan.csv")
feb = pd.read_csv("library/checkouts_feb.csv")

# %%
jan.head()
# Out:
#       Branch  Member ID  Book ID
# 0   Westside        587        5
# 1  Northpark        158       25
# 2   Downtown        820       23
# 3   Downtown        800       29
# 4  Northpark        150       19

# %%
books.head()
# Out:
#    Book ID                    Title               Author        Genre
# 0        1    To Kill a Mockingbird           Harper Lee      Fiction
# 1        2                     1984        George Orwell      Fiction
# 2        3  A Brief History of Time      Stephen Hawking      Science
# 3        4         The Great Gatsby  F. Scott Fitzgerald      Fiction
# 4        5             Freakonomics        Steven Levitt  Non-Fiction

# %%
jan.merge(books, how="left", on="Book ID")
# Out:
#         Branch  Member ID  Book ID             Title               Author  \
# 0     Westside        587        5      Freakonomics        Steven Levitt
# 1    Northpark        158       25     Atomic Habits          James Clear
# 2     Downtown        820       23         Gone Girl        Gillian Flynn
# 3     Downtown        800       29      Little Women    Louisa May Alcott
# 4    Northpark        150       19    Fahrenheit 451         Ray Bradbury
# ..         ...        ...      ...               ...                  ...
# 245   Eastgate        491        4  The Great Gatsby  F. Scott Fitzgerald
# 246  Riverside        196       25     Atomic Habits          James Clear
# 247   Downtown        770        7          Educated        Tara Westover
# 248   Westside        770        7          Educated        Tara Westover
# 249  Northpark        312       28      Ender's Game     Orson Scott Card
#
#            Genre
# 0    Non-Fiction
# 1    Non-Fiction
# 2        Fiction
# 3        Fiction
# 4         Sci-Fi
# ..           ...
# 245      Fiction
# 246  Non-Fiction
# 247       Memoir
# 248       Memoir
# 249       Sci-Fi
#
# [250 rows x 6 columns]

# %% [markdown]
# ## The left_on and right_on Parameters
# - The `left_on` and `right_on` parameters designate the column names from each `DataFrame` to use in the merge.

# %%
books = pd.read_csv("library/books.csv")
members = pd.read_csv("library/members.csv", parse_dates=["Signup Date"])
jan = pd.read_csv("library/checkouts_jan.csv")
feb = pd.read_csv("library/checkouts_feb.csv")

# %%
jan.merge(books, how="left", on="Book ID")
# Out:
#         Branch  Member ID  Book ID             Title               Author  \
# 0     Westside        587        5      Freakonomics        Steven Levitt
# 1    Northpark        158       25     Atomic Habits          James Clear
# 2     Downtown        820       23         Gone Girl        Gillian Flynn
# 3     Downtown        800       29      Little Women    Louisa May Alcott
# 4    Northpark        150       19    Fahrenheit 451         Ray Bradbury
# ..         ...        ...      ...               ...                  ...
# 245   Eastgate        491        4  The Great Gatsby  F. Scott Fitzgerald
# 246  Riverside        196       25     Atomic Habits          James Clear
# 247   Downtown        770        7          Educated        Tara Westover
# 248   Westside        770        7          Educated        Tara Westover
# 249  Northpark        312       28      Ender's Game     Orson Scott Card
#
#            Genre
# 0    Non-Fiction
# 1    Non-Fiction
# 2        Fiction
# 3        Fiction
# 4         Sci-Fi
# ..           ...
# 245      Fiction
# 246  Non-Fiction
# 247       Memoir
# 248       Memoir
# 249       Sci-Fi
#
# [250 rows x 6 columns]

# %%
jan.merge(members, how="left", left_on="Member ID", right_on="ID").drop(columns=["ID"])
# Out:
#         Branch  Member ID  Book ID First Name Last Name  \
# 0     Westside        587        5  Alexander      Ward
# 1    Northpark        158       25     Nicole       Kim
# 2     Downtown        820       23   Kathleen      Hall
# 3     Downtown        800       29    Heather      King
# 4    Northpark        150       19    Matthew    Nguyen
# ..         ...        ...      ...        ...       ...
# 245   Eastgate        491        4       Mark     Patel
# 246  Riverside        196       25    Timothy   Roberts
# 247   Downtown        770        7       Lisa     James
# 248   Westside        770        7       Lisa     James
# 249  Northpark        312       28       Jack     Ortiz
#
#                             Email Membership Signup Date
# 0     alexander.ward81@icloud.com      Basic  2020-10-12
# 1          nicole.kim80@yahoo.com    Student  2022-02-18
# 2      kathleen.hall85@icloud.com      Basic  2024-08-19
# 3        heather.king67@yahoo.com      Basic  2022-04-19
# 4    matthew.nguyen30@outlook.com      Basic  2020-01-29
# ..                            ...        ...         ...
# 245        mark.patel19@gmail.com      Basic  2023-04-11
# 246   timothy.roberts85@yahoo.com    Premium  2020-03-16
# 247        lisa.james72@yahoo.com      Basic  2022-08-22
# 248        lisa.james72@yahoo.com      Basic  2022-08-22
# 249       jack.ortiz5@outlook.com    Student  2023-06-19
#
# [250 rows x 8 columns]

# %% [markdown]
# ## Inner Joins I
# - Inner joins merge two tables based on *shared*/*common* values in columns.
# - If only one `DataFrame` has a value, pandas will exclude it from the final results set.
# - If the same ID occurs multiple times, pandas will store each possible combination of the values.
# - The design of the join ensures that the results will be the same no matter what `DataFrame` the `merge` method is invoked upon.
# <img src="assets/SQL_Joins.png" width="800" height="800"/>

# %%
books = pd.read_csv("library/books.csv")
members = pd.read_csv("library/members.csv", parse_dates=["Signup Date"])
jan = pd.read_csv("library/checkouts_jan.csv")
feb = pd.read_csv("library/checkouts_feb.csv")

# %% [markdown]
# - Let's identify the members who checked out a book in both January and February.

# %%
jan.head()
# Out:
#       Branch  Member ID  Book ID
# 0   Westside        587        5
# 1  Northpark        158       25
# 2   Downtown        820       23
# 3   Downtown        800       29
# 4  Northpark        150       19

# %%
feb.head()
# Out:
#       Branch  Member ID  Book ID
# 0  Riverside         80        3
# 1   Eastgate        753       33
# 2   Downtown         39       19
# 3   Westside        300       30
# 4   Eastgate          5       13

# %%
jan.merge(feb, how="inner", on="Member ID")
jan.merge(feb, how="inner", on="Member ID", suffixes=[" - Jan", " - Feb"])
# Out:
#     Branch - Jan  Member ID  Book ID - Jan Branch - Feb  Book ID - Feb
# 0       Westside        587              5     Eastgate             34
# 1      Northpark        150             19     Eastgate             18
# 2      Northpark        150             19     Westside             18
# 3       Eastgate        178             10    Riverside             20
# 4       Eastgate        178             10    Northpark             11
# ..           ...        ...            ...          ...            ...
# 163    Northpark        201             14    Northpark             22
# 164    Riverside        587             17     Eastgate             34
# 165     Eastgate        925              9     Westside             29
# 166    Northpark        351              6    Northpark             30
# 167    Northpark        351              6     Downtown             29
#
# [168 rows x 5 columns]

# %%
jan[jan["Member ID"] == 178]
# Out:
#      Branch  Member ID  Book ID
# 7  Eastgate        178       10

# %%
feb[feb["Member ID"] == 178]
# Out:
#         Branch  Member ID  Book ID
# 170  Riverside        178       20
# 233  Northpark        178       11

# %% [markdown]
# ## Matching across Multiple Columns
# - We can pass a list of multiple columns to the `on` parameter of the `merge` method.
# - Pandas will require matching values in both columns across the two `DataFrames`.

# %%
books = pd.read_csv("library/books.csv")
members = pd.read_csv("library/members.csv", parse_dates=["Signup Date"])
jan = pd.read_csv("library/checkouts_jan.csv")
feb = pd.read_csv("library/checkouts_feb.csv")

# %% [markdown]
# - Let's identify the members who checked out the _same_ in book January and February.

# %%
jan.merge(feb, how="inner", on=["Member ID", "Book ID"])
# Out:
#     Branch_x  Member ID  Book ID   Branch_y
# 0   Eastgate        896        5  Riverside
# 1  Northpark         17       27  Riverside
# 2   Downtown         34       17   Eastgate
# 3   Eastgate        299       27  Northpark
# 4   Westside         29       35   Eastgate

# %%
condition_one = jan["Member ID"] == 896
condition_two = jan["Book ID"] == 5
jan[condition_one & condition_two]
# Out:
#      Branch  Member ID  Book ID
# 8  Eastgate        896        5

# %%
condition_one = feb["Member ID"] == 896
condition_two = feb["Book ID"] == 5
feb[condition_one & condition_two]
# Out:
#        Branch  Member ID  Book ID
# 57  Riverside        896        5

# %% [markdown]
# ## Full/Outer Join
# - A **full/outer** join includes values that are found in either `DataFrame` or both `DataFrame` objects.
# - Pandas does not mind if a value exists in one `DataFrame` but not the other.
# - If a value does not exist in one `DataFrame`, it will have a `NaN`.
#
# <img src="assets/SQL_Joins.png" width="800" height="800"/>

# %%
books = pd.read_csv("library/books.csv")
members = pd.read_csv("library/members.csv", parse_dates=["Signup Date"])
jan = pd.read_csv("library/checkouts_jan.csv")
feb = pd.read_csv("library/checkouts_feb.csv")

# %%
jan.merge(feb, how="outer", on="Member ID", suffixes=[" - Jan", " - Feb"])
merged = jan.merge(
    feb, how="outer", on="Member ID", suffixes=[" - Jan", " - Feb"], indicator=True
)
merged.head()
# Out:
#   Branch - Jan  Member ID  Book ID - Jan Branch - Feb  Book ID - Feb  \
# 0          NaN          2            NaN     Eastgate           19.0
# 1          NaN          5            NaN     Eastgate           13.0
# 2          NaN          5            NaN    Riverside           10.0
# 3          NaN          5            NaN     Westside           21.0
# 4          NaN          5            NaN    Northpark           16.0
#
#        _merge
# 0  right_only
# 1  right_only
# 2  right_only
# 3  right_only
# 4  right_only

# %%
merged["_merge"].value_counts()
# Out:
# _merge
# both          168
# left_only     151
# right_only    149
# Name: count, dtype: int64

# %%
merged[merged["_merge"] == "both"]
merged[merged["_merge"] == "left_only"]
merged[merged["_merge"] == "right_only"]
# Out:
#     Branch - Jan  Member ID  Book ID - Jan Branch - Feb  Book ID - Feb  \
# 0            NaN          2            NaN     Eastgate           19.0
# 1            NaN          5            NaN     Eastgate           13.0
# 2            NaN          5            NaN    Riverside           10.0
# 3            NaN          5            NaN     Westside           21.0
# 4            NaN          5            NaN    Northpark           16.0
# ..           ...        ...            ...          ...            ...
# 452          NaN        945            NaN     Eastgate           21.0
# 463          NaN        962            NaN     Eastgate           11.0
# 464          NaN        966            NaN     Eastgate            9.0
# 465          NaN        982            NaN     Eastgate           17.0
# 466          NaN        982            NaN     Eastgate           22.0
#
#          _merge
# 0    right_only
# 1    right_only
# 2    right_only
# 3    right_only
# 4    right_only
# ..          ...
# 452  right_only
# 463  right_only
# 464  right_only
# 465  right_only
# 466  right_only
#
# [149 rows x 6 columns]

# %%
merged[merged["_merge"].isin(["left_only", "right_only"])]
# Out:
#     Branch - Jan  Member ID  Book ID - Jan Branch - Feb  Book ID - Feb  \
# 0            NaN          2            NaN     Eastgate           19.0
# 1            NaN          5            NaN     Eastgate           13.0
# 2            NaN          5            NaN    Riverside           10.0
# 3            NaN          5            NaN     Westside           21.0
# 4            NaN          5            NaN    Northpark           16.0
# ..           ...        ...            ...          ...            ...
# 463          NaN        962            NaN     Eastgate           11.0
# 464          NaN        966            NaN     Eastgate            9.0
# 465          NaN        982            NaN     Eastgate           17.0
# 466          NaN        982            NaN     Eastgate           22.0
# 467     Downtown        992           29.0          NaN            NaN
#
#          _merge
# 0    right_only
# 1    right_only
# 2    right_only
# 3    right_only
# 4    right_only
# ..          ...
# 463  right_only
# 464  right_only
# 465  right_only
# 466  right_only
# 467   left_only
#
# [300 rows x 6 columns]

# %% [markdown]
# ## Merging by Indexes with the left_index and right_index Parameters
# - Use the `on` parameter if the column(s) to be matched on have the same names in both `DataFrame` objects.
# - Use the `left_on` and `right_on` parameters if the columns with matches have different names.
# - Use the `left_index` or `right_index` parameters (set to `True`) if the values to be matched are found in a `DataFrame` index.

# %%
books = pd.read_csv("library/books.csv", index_col="Book ID")
members = pd.read_csv(
    "library/members.csv", parse_dates=["Signup Date"], index_col="ID"
)
jan = pd.read_csv("library/checkouts_jan.csv")
feb = pd.read_csv("library/checkouts_feb.csv")

# %%
books.head(2)
# Out:
#                          Title         Author    Genre
# Book ID
# 1        To Kill a Mockingbird     Harper Lee  Fiction
# 2                         1984  George Orwell  Fiction

# %%
members.head(2)
# Out:
#    First Name Last Name                           Email Membership Signup Date
# ID
# 1    Samantha  Anderson  samantha.anderson4@outlook.com      Basic  2020-10-12
# 2        Jack    Wilson         jack.wilson87@proton.me      Basic  2022-05-14

# %%
jan.merge(members, how="left", left_on="Member ID", right_index=True).merge(
    books, how="left", left_on="Book ID", right_index=True
)
# Out:
#         Branch  Member ID  Book ID First Name Last Name  \
# 0     Westside        587        5  Alexander      Ward
# 1    Northpark        158       25     Nicole       Kim
# 2     Downtown        820       23   Kathleen      Hall
# 3     Downtown        800       29    Heather      King
# 4    Northpark        150       19    Matthew    Nguyen
# ..         ...        ...      ...        ...       ...
# 245   Eastgate        491        4       Mark     Patel
# 246  Riverside        196       25    Timothy   Roberts
# 247   Downtown        770        7       Lisa     James
# 248   Westside        770        7       Lisa     James
# 249  Northpark        312       28       Jack     Ortiz
#
#                             Email Membership Signup Date             Title  \
# 0     alexander.ward81@icloud.com      Basic  2020-10-12      Freakonomics
# 1          nicole.kim80@yahoo.com    Student  2022-02-18     Atomic Habits
# 2      kathleen.hall85@icloud.com      Basic  2024-08-19         Gone Girl
# 3        heather.king67@yahoo.com      Basic  2022-04-19      Little Women
# 4    matthew.nguyen30@outlook.com      Basic  2020-01-29    Fahrenheit 451
# ..                            ...        ...         ...               ...
# 245        mark.patel19@gmail.com      Basic  2023-04-11  The Great Gatsby
# 246   timothy.roberts85@yahoo.com    Premium  2020-03-16     Atomic Habits
# 247        lisa.james72@yahoo.com      Basic  2022-08-22          Educated
# 248        lisa.james72@yahoo.com      Basic  2022-08-22          Educated
# 249       jack.ortiz5@outlook.com    Student  2023-06-19      Ender's Game
#
#                   Author        Genre
# 0          Steven Levitt  Non-Fiction
# 1            James Clear  Non-Fiction
# 2          Gillian Flynn      Fiction
# 3      Louisa May Alcott      Fiction
# 4           Ray Bradbury       Sci-Fi
# ..                   ...          ...
# 245  F. Scott Fitzgerald      Fiction
# 246          James Clear  Non-Fiction
# 247        Tara Westover       Memoir
# 248        Tara Westover       Memoir
# 249     Orson Scott Card       Sci-Fi
#
# [250 rows x 11 columns]

# %% [markdown]
# ## The join Method
# - The `join` method is a shortcut for joining two `DataFrames` using index labels.

# %%
books = pd.read_csv("library/books.csv")
members = pd.read_csv(
    "library/members.csv", parse_dates=["Signup Date"], index_col="ID"
).sort_index()
jan = pd.read_csv("library/checkouts_jan.csv", index_col="Member ID")
feb = pd.read_csv("library/checkouts_feb.csv")

# %%
jan.head(2)
# Out:
#               Branch  Book ID
# Member ID
# 587         Westside        5
# 158        Northpark       25

# %%
members.head(2)
# Out:
#    First Name Last Name                           Email Membership Signup Date
# ID
# 1    Samantha  Anderson  samantha.anderson4@outlook.com      Basic  2020-10-12
# 2        Jack    Wilson         jack.wilson87@proton.me      Basic  2022-05-14

# %%
jan.merge(members, how="left", left_index=True, right_index=True)
# Out:
#               Branch  Book ID First Name Last Name  \
# Member ID
# 587         Westside        5  Alexander      Ward
# 158        Northpark       25     Nicole       Kim
# 820         Downtown       23   Kathleen      Hall
# 800         Downtown       29    Heather      King
# 150        Northpark       19    Matthew    Nguyen
# ...              ...      ...        ...       ...
# 491         Eastgate        4       Mark     Patel
# 196        Riverside       25    Timothy   Roberts
# 770         Downtown        7       Lisa     James
# 770         Westside        7       Lisa     James
# 312        Northpark       28       Jack     Ortiz
#
#                                   Email Membership Signup Date
# Member ID
# 587         alexander.ward81@icloud.com      Basic  2020-10-12
# 158              nicole.kim80@yahoo.com    Student  2022-02-18
# 820          kathleen.hall85@icloud.com      Basic  2024-08-19
# 800            heather.king67@yahoo.com      Basic  2022-04-19
# 150        matthew.nguyen30@outlook.com      Basic  2020-01-29
# ...                                 ...        ...         ...
# 491              mark.patel19@gmail.com      Basic  2023-04-11
# 196         timothy.roberts85@yahoo.com    Premium  2020-03-16
# 770              lisa.james72@yahoo.com      Basic  2022-08-22
# 770              lisa.james72@yahoo.com      Basic  2022-08-22
# 312             jack.ortiz5@outlook.com    Student  2023-06-19
#
# [250 rows x 7 columns]

# %%
jan.join(members)
# Out:
#               Branch  Book ID First Name Last Name  \
# Member ID
# 587         Westside        5  Alexander      Ward
# 158        Northpark       25     Nicole       Kim
# 820         Downtown       23   Kathleen      Hall
# 800         Downtown       29    Heather      King
# 150        Northpark       19    Matthew    Nguyen
# ...              ...      ...        ...       ...
# 491         Eastgate        4       Mark     Patel
# 196        Riverside       25    Timothy   Roberts
# 770         Downtown        7       Lisa     James
# 770         Westside        7       Lisa     James
# 312        Northpark       28       Jack     Ortiz
#
#                                   Email Membership Signup Date
# Member ID
# 587         alexander.ward81@icloud.com      Basic  2020-10-12
# 158              nicole.kim80@yahoo.com    Student  2022-02-18
# 820          kathleen.hall85@icloud.com      Basic  2024-08-19
# 800            heather.king67@yahoo.com      Basic  2022-04-19
# 150        matthew.nguyen30@outlook.com      Basic  2020-01-29
# ...                                 ...        ...         ...
# 491              mark.patel19@gmail.com      Basic  2023-04-11
# 196         timothy.roberts85@yahoo.com    Premium  2020-03-16
# 770              lisa.james72@yahoo.com      Basic  2022-08-22
# 770              lisa.james72@yahoo.com      Basic  2022-08-22
# 312             jack.ortiz5@outlook.com    Student  2023-06-19
#
# [250 rows x 7 columns]
